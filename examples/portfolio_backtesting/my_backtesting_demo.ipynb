# %%
#%%
from datetime import datetime
from importlib import reload

import sys
sys.path.append('/Users/jessealdridge/Dropbox/vnpy')

import vnpy.app.portfolio_strategy
reload(vnpy.app.portfolio_strategy)

from vnpy.app.portfolio_strategy import BacktestingEngine
from vnpy.trader.constant import Interval

import vnpy.app.portfolio_strategy.strategies.my_trend_following_strategy as stg
reload(stg)
from vnpy.app.portfolio_strategy.strategies.my_trend_following_strategy import MyTrendFollowingStrategy

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbols=["AAPL.NYSE", "MSFT.NYSE"],
    interval=Interval.MINUTE,
    start=datetime(2019, 1, 1),
    end=datetime(2020, 4, 30),
    rates={
        "AAPL.NYSE": 0/10000,
        "MSFT.NYSE": 0/10000
    },
    slippages={
        "AAPL.NYSE": 0,
        "MSFT.NYSE": 0
    },
    sizes={
        "AAPL.NYSE": 10,
        "MSFT.NYSE": 10
    },
    priceticks={
        "AAPL.NYSE": 1,
        "MSFT.NYSE": 1
    },
    capital=1_000_000,
)

setting = {
    "boll_window": 20,
    "boll_dev": 1,
}
engine.add_strategy(MyTrendFollowingStrategy, setting)

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2020-08-25 16:30:21.716960	Start loading historical data
# 2020-08-25 16:30:21.717345	AAPL.NYSE Loading progress： [6%]
# 2020-08-25 16:30:21.717413	AAPL.NYSE Loading progress：# [12%]
# 2020-08-25 16:30:21.717454	AAPL.NYSE Loading progress：# [19%]
# 2020-08-25 16:30:21.717487	AAPL.NYSE Loading progress：## [25%]
# 2020-08-25 16:30:21.717550	AAPL.NYSE Loading progress：### [31%]
# 2020-08-25 16:30:21.717607	AAPL.NYSE Loading progress：### [37%]
# 2020-08-25 16:30:21.717645	AAPL.NYSE Loading progress：#### [43%]
# 2020-08-25 16:30:21.717681	AAPL.NYSE Loading progress：#### [49%]
# 2020-08-25 16:30:21.717715	AAPL.NYSE Loading progress：##### [56%]
# 2020-08-25 16:30:21.717743	AAPL.NYSE Loading progress：###### [62%]
# 2020-08-25 16:30:21.717769	AAPL.NYSE Loading progress：###### [68%]
# 2020-08-25 16:30:21.717795	AAPL.NYSE Loading progress：####### [74%]
# 2020-08-25 16:30:21.717818	AAPL.NYSE Loading progress：######## [80%]
# 2020-08-25 16:30:21.717839	AAPL.NYSE Loading progress：######## [87%]
# ...
